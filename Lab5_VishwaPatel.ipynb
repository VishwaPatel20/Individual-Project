# %% [markdown]
# LAB 5

# %% [markdown]
# Part 1 : Frequency counts

# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import csv file
df = pd.read_csv("Salaries.csv")

# %%
df.head(20)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
#Count the number of unique values in our data
df.rank.value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 #Count the number of unique values in our data
# ----> 2 df.rank.value_counts(dropna=False)
#
# AttributeError: 'function' object has no attribute 'value_counts'

# %% [markdown]
# This is due to the fact that rank is a Python keyword and cannot be a variable.

# %%
#Printing info for each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %% [markdown]
# Part 2: Summary statistics and filtering

# %%
#returns description of the data in the DataFrame
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
#sort the data with the value in the salary column greater than 120K
df_sub = df[ df['salary'] > 120000]
df_sub.head()
# Out:
#     rank discipline  phd  service   sex  salary
# 0   Prof          B   56       49  Male  186960
# 3   Prof          A   40       31  Male  131205
# 5   Prof          A   20       20  Male  122400
# 7   Prof          A   18       18  Male  126300
# 10  Prof          B   39       33  Male  128250

# %%
# returns a list of row and column axis labels of the DataFrame
df_sub.axes
# Out:
# [Index([ 0,  3,  5,  7, 10, 11, 13, 14, 15, 19, 26, 27, 29, 31, 35, 36, 39, 40,
#         44, 45, 49, 51, 58, 72, 75],
#        dtype='int64'),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
#Select data for female professors
df_female = df[ df['sex'] == 'Female']
df_female.head()
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000

# %%
# finding the mean value of the salary for the discipline A
df[ df['discipline'] =='A'].salary.mean()
# Out:
# 98331.11111111111

# %% [markdown]
# Part 3: Slicing the dataset

# %%
#Select column salary
df1 = df['salary']

# %%
#Check data type of the dataframe.
type(df1)
# Out:
# pandas.core.series.Series

# %%
#Look at the first few elements of the output
df1.head()
# Out:
# 0    186960
# 1     93000
# 2    110515
# 3    131205
# 4    104800
# Name: salary, dtype: int64

# %%
#Select column salary and make the output to be a data frame
df2 = df[['salary']]

# %%
df2
# Out:
#     salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# 74  104542
# 75  124312
# 76  109954
# 77  109646
#
# [78 rows x 1 columns]

# %%
#Check the type
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
#Select a subset of rows
df_first10_rows=df[0:11]
df_first10_rows.head(5)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#If we want to select specific rows
df_sub=df.loc[10:20,['rank', 'sex','salary']]

# %%
df_sub
# Out:
#         rank   sex  salary
# 10      Prof  Male  128250
# 11      Prof  Male  134778
# 12  AsstProf  Male   88000
# 13      Prof  Male  162200
# 14      Prof  Male  153750
# 15      Prof  Male  150480
# 16  AsstProf  Male   75044
# 17  AsstProf  Male   92000
# 18      Prof  Male  107300
# 19      Prof  Male  150500
# 20  AsstProf  Male   92000

# %%
df_sub.head(3)
# Out:
#         rank   sex  salary
# 10      Prof  Male  128250
# 11      Prof  Male  134778
# 12  AsstProf  Male   88000

# %%
#  Unlike method .loc, method iloc selects rows by poistion:
df.iloc[0:10,[0,4]]
# Out:
#         rank   sex
# 0       Prof  Male
# 1       Prof  Male
# 2       Prof  Male
# 3       Prof  Male
# 4       Prof  Male
# 5       Prof  Male
# 6  AssocProf  Male
# 7       Prof  Male
# 8       Prof  Male
# 9       Prof  Male

# %% [markdown]
# Part 4: Sorting the Data

# %%
#Sort by 'service' column  
df_sorted = df.sort_values(by = 'service')
df_sorted.head()
# Out:
#         rank discipline  phd  service     sex  salary
# 55  AsstProf          A    2        0  Female   72500
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000

# %%
#Sort by 'service' in descending order
df.sort_values(by = 'service', ascending = False, inplace = True)
df.head()
# Out:
#     rank discipline  phd  service     sex  salary
# 9   Prof          A   51       51    Male   57800
# 0   Prof          B   56       49    Male  186960
# 36  Prof          B   45       45    Male  146856
# 27  Prof          A   45       43    Male  155865
# 40  Prof          A   39       36  Female  137000

# %%
# Restore the original order
df.sort_index(axis=0, ascending = True, inplace = True)
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %% [markdown]
# Part 5: Explore data using graphics

# %%
#Show graphs withint Python notebook
# %matplotlib inline

# %%
#to draw a histogram of a salary data
plt.hist(df['salary'],bins=10, density= True)
plt.show()

# %%
# Use regular matplotlib function to display a barplot
df.groupby(['rank'])['salary'].count().plot(kind='bar')
plt.show()

# %%
#Scatterplot in seaborn
sns.jointplot(x='service', y='salary', data=df)
plt.show()
